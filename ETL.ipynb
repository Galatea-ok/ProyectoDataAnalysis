# %% [markdown]
# # ETL

# %% [markdown]
# ## comienzo importando las librerias necesarias

# %%
import pandas as pd 
import numpy as np
from datetime import datetime

# %% [markdown]
# ## continuo con la carga de los datos

# %%
dfa = pd.read_csv('AccidentesAviones.csv')
dfa.sample(5)
# Out:
#       Unnamed: 0               fecha HORA declarada                    Ruta  \
# 1283        1283    October 27, 1951           1900  Near Flores, Guatemala
# 1885        1885   February 15, 1961           1005  Near Brussels, Belgium
# 1783        1783  September 08, 1959              ?       Poza Rica, Mexico
# 4746        4746    October 17, 2009           1238     Manila, Philippines
# 4545        4545      March 16, 2005           1357        Varandey, Russia
#
#                              OperadOR flight_no  \
# 1283  Military - Guatemalan Air Force         ?
# 1885                           Sabena       548
# 1783                         Mexicana         ?
# 4746                     Victoria Air         ?
# 4545                Regional Airlines         ?
#
#                                             route           ac_type  \
# 1283                      Flores - Guatemala City      Douglas C-47
# 1885                     New York City - Brussels  Boeing B-707-320
# 1783                         Mexico City - Merida      Douglas DC-3
# 4746        Manila - Puerto Princesa, Philippines     Douglas DC-3C
# 4545  Ufa - Usinsk - Perm - Varandey - Naryan Mar        Antonov 24
#
#      registration        cn_ln all_aboard PASAJEROS A BORDO crew_aboard  \
# 1283      FAGO961            ?         29                25           4
# 1885       OO-SJB     17624/92         72                61          11
# 1783            ?            ?         16                13           3
# 4746       RPC550  25737/14292          4                 0           4
# 4545     RA-46489     27308107         52                45           7
#
#      cantidad de fallecidos passenger_fatalities crew_fatalities ground  \
# 1283                     27                   23               4      0
# 1885                     72                   61              11      1
# 1783                      1                    1               0      0
# 4746                      4                    0               4      0
# 4545                     28                   26               2      0
#
#                                                 summary
# 1283  Crashed and burned in jungle 170 miles north n...
# 1885  The aircraft was about to touchdown on the run...
# 1783  An in-flight explosion occurred in the passeng...
# 4746  Shortly after take off the crew reported engin...
# 4545  The  Russian turboprop carrying oil workers, c...

# %% [markdown]
# ## A continuacion presento el **diccionario de datos**

# %% [markdown]
# ###
# - ***Unnamed: 0:*** Indice para cada registro de accidente de vuelo
# - ***fecha:*** Fecha en la que ocurrió el accidente de vuelo
# - ***HORA declarada:*** Hora declarada del accidente aéreo
# - ***Ruta:*** Ubicación geográfica donde ocurrió el accidente de vuelo
# - ***OperadOR:*** Compañía aérea operadora del vuelo
# - ***flight_no:*** Número de vuelo
# - ***route:*** Ruta del vuelo, indicando los puntos de partida y destino
# - ***ac_type:*** Tipo de aeronave involucrada en el accidente
# - ***registration:*** Número de registro o matrícula de la aeronave
# - ***cn_ln:*** Número de serie de la aeronave
# - ***all_aboard:*** Total de personas a bordo (pasajeros y tripulación)
# - ***PASAJEROS A BORDO:*** Total de pasajeros a bordo
# - ***crew_aboard:*** Total de tripulación a bordo
# - ***cantidad de fallecidos:*** Total de personas fallecidas en el accidente (pasajeros y tripulación)
# - ***passenger_fatalities:*** Total de pasajeros fallecidos en el accidente
# - ***crew_fatalities:*** Total de tripulantes fallecidos en el accidente
# - ***ground:*** Total de personas en tierra fallecidas en el accidente
# - ***summary:*** Resumen del accidente de vuelo y las circunstancias asociadas

# %% [markdown]
# # Observaciones

# %% [markdown]
# > Se ha recibido un set de datos que contiene 5008 registros en 18 columnas.
# > Ante el primer contacto con los datos se observa:
# > * La exitencia de una columna con datos innecesarios:"Unnamed: 0"
# > * En algunas columnas aparece el caracter "?" representando la ausencia de dato.

# %% [markdown]
# ##### Cuantificación de la presencia del caracter "?" en cada una de las columnas y su incidencia

# %%
columns = dfa.columns
pd.DataFrame(["Cantidad de '?' en '"+columns+"': "+str(dfa[dfa[columns] == "?"][columns].count()) for columns in columns]).style.hide().hide(axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c404">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8c404_row0_col0" class="data row0 col0" >Cantidad de '?' en 'Unnamed: 0': 0</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row1_col0" class="data row1 col0" >Cantidad de '?' en 'fecha': 0</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row2_col0" class="data row2 col0" >Cantidad de '?' en 'HORA declarada': 1504</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row3_col0" class="data row3 col0" >Cantidad de '?' en 'Ruta': 5</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row4_col0" class="data row4 col0" >Cantidad de '?' en 'OperadOR': 10</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row5_col0" class="data row5 col0" >Cantidad de '?' en 'flight_no': 3682</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row6_col0" class="data row6 col0" >Cantidad de '?' en 'route': 762</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row7_col0" class="data row7 col0" >Cantidad de '?' en 'ac_type': 13</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row8_col0" class="data row8 col0" >Cantidad de '?' en 'registration': 272</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row9_col0" class="data row9 col0" >Cantidad de '?' en 'cn_ln': 667</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row10_col0" class="data row10 col0" >Cantidad de '?' en 'all_aboard': 17</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row11_col0" class="data row11 col0" >Cantidad de '?' en 'PASAJEROS A BORDO': 221</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row12_col0" class="data row12 col0" >Cantidad de '?' en 'crew_aboard': 219</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row13_col0" class="data row13 col0" >Cantidad de '?' en 'cantidad de fallecidos': 8</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row14_col0" class="data row14 col0" >Cantidad de '?' en 'passenger_fatalities': 235</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row15_col0" class="data row15 col0" >Cantidad de '?' en 'crew_fatalities': 235</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row16_col0" class="data row16 col0" >Cantidad de '?' en 'ground': 44</td>
#     </tr>
#     <tr>
#       <td id="T_8c404_row17_col0" class="data row17 col0" >Cantidad de '?' en 'summary': 59</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Transformaciones

# %% [markdown]
# ### Cambio el nombre de cada columna respetando el idioma Ingles

# %%
dfa.rename(columns={
    "Unnamed: 0" : "Index",
    "fecha": "Date",
    "HORA declarada": "Event_Time",
    "Ruta": "Location",
    "OperadOR": "Operator",
    "flight_no": "Flight_Number",
    "route": "Route",
    "ac_type": "Aircraft_Type",
    "registration": "Registration",
    "cn_ln": "AC_SerialNumber",
    "all_aboard": "Aboard_Total",
    "PASAJEROS A BORDO": "Passengers_Aboard",
    "crew_aboard": "Crew_Aboard",
    "cantidad de fallecidos": "Total_Fatalities",
    "passenger_fatalities" : "Passenger_Fatalities",
    "crew_fatalities" : "Crew_Fatalities",
    "ground" : "Fatalities_From_Ground",
    "summary" : "Summary"
    }, inplace=True)

# %% [markdown]
# #### Reemplazo de la presencia del caracter "?" en cada una de las columnas por NA Type

# %%
dfa.replace('?', pd.NA, inplace=True)

# %%
dfa.head()
# Out:
#    Index                Date Event_Time                            Location  \
# 0      0  September 17, 1908       1718                 Fort Myer, Virginia
# 1      1  September 07, 1909       <NA>             Juvisy-sur-Orge, France
# 2      2       July 12, 1912       0630           Atlantic City, New Jersey
# 3      3     August 06, 1913       <NA>  Victoria, British Columbia, Canada
# 4      4  September 09, 1913       1830                  Over the North Sea
#
#                  Operator Flight_Number          Route  \
# 0    Military - U.S. Army          <NA>  Demonstration
# 1                    <NA>          <NA>       Air show
# 2    Military - U.S. Navy          <NA>    Test flight
# 3                 Private          <NA>           <NA>
# 4  Military - German Navy          <NA>           <NA>
#
#             Aircraft_Type Registration AC_SerialNumber Aboard_Total  \
# 0        Wright Flyer III         <NA>               1            2
# 1          Wright Byplane          SC1            <NA>            1
# 2               Dirigible         <NA>            <NA>            5
# 3        Curtiss seaplane         <NA>            <NA>            1
# 4  Zeppelin L-1 (airship)         <NA>            <NA>           20
#
#   Passengers_Aboard Crew_Aboard Total_Fatalities Passenger_Fatalities  \
# 0                 1           1                1                    1
# 1                 0           1                1                    0
# 2                 0           5                5                    0
# 3                 0           1                1                    0
# 4              <NA>        <NA>               14                 <NA>
#
#   Crew_Fatalities Fatalities_From_Ground  \
# 0               0                      0
# 1               0                      0
# 2               5                      0
# 3               1                      0
# 4            <NA>                      0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  Eugene Lefebvre was the first pilot to ever be...
# 2  First U.S. dirigible Akron exploded just offsh...
# 3  The first fatal airplane accident in Canada oc...
# 4  The airship flew into a thunderstorm and encou...

# %% [markdown]
# # En perspectivas de hacer un grafico de Areas y Paises...

# %%
# Importo desde el DataSet complementario

df_country = pd.read_csv("Pais.csv")
df_country.rename(columns={'Unnamed: 0' : 'Index'}, inplace=True)

# %%
# Combino el DataSet complementario con mi DataFrame final

df_crashes = pd.merge(dfa , df_country, on= 'Index')
df_crashes.head()
# Out:
#    Index                Date Event_Time                            Location  \
# 0      0  September 17, 1908       1718                 Fort Myer, Virginia
# 1      1  September 07, 1909       <NA>             Juvisy-sur-Orge, France
# 2      2       July 12, 1912       0630           Atlantic City, New Jersey
# 3      3     August 06, 1913       <NA>  Victoria, British Columbia, Canada
# 4      4  September 09, 1913       1830                  Over the North Sea
#
#                  Operator Flight_Number          Route  \
# 0    Military - U.S. Army          <NA>  Demonstration
# 1                    <NA>          <NA>       Air show
# 2    Military - U.S. Navy          <NA>    Test flight
# 3                 Private          <NA>           <NA>
# 4  Military - German Navy          <NA>           <NA>
#
#             Aircraft_Type Registration AC_SerialNumber Aboard_Total  \
# 0        Wright Flyer III         <NA>               1            2
# 1          Wright Byplane          SC1            <NA>            1
# 2               Dirigible         <NA>            <NA>            5
# 3        Curtiss seaplane         <NA>            <NA>            1
# 4  Zeppelin L-1 (airship)         <NA>            <NA>           20
#
#   Passengers_Aboard Crew_Aboard Total_Fatalities Passenger_Fatalities  \
# 0                 1           1                1                    1
# 1                 0           1                1                    0
# 2                 0           5                5                    0
# 3                 0           1                1                    0
# 4              <NA>        <NA>               14                 <NA>
#
#   Crew_Fatalities Fatalities_From_Ground  \
# 0               0                      0
# 1               0                      0
# 2               5                      0
# 3               1                      0
# 4            <NA>                      0
#
#                                              Summary        country
# 0  During a demonstration flight, a U.S. Army fly...  United States
# 1  Eugene Lefebvre was the first pilot to ever be...         France
# 2  First U.S. dirigible Akron exploded just offsh...  United States
# 3  The first fatal airplane accident in Canada oc...         Canada
# 4  The airship flew into a thunderstorm and encou...  United States

# %%
# Exportamos a un dataset final de nombre 'AircraftCrash.csv' para el EDA

dfa.to_csv('AircraftCrash.csv', index = False)
